# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student_pass_fail.csv')
df.head()
# Out:
#    StudyHours  Attendance  PreviousScore  Pass
# 0           1          55             40     0
# 1           2          60             45     0
# 2           3          58             50     0
# 3           2          65             48     0
# 4           4          70             55     1

# %%
df.isnull().sum()
# Out:
# StudyHours       0
# Attendance       0
# PreviousScore    0
# Pass             0
# dtype: int64

# %%
import seaborn as sns
sns.pairplot(df, hue="Pass", palette="Set1")
plt.show()

# %%
X = df.drop('Pass', axis='columns')
y = df['Pass']

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X,y)
# Out:
# LogisticRegression()

# %%
model.predict([[2,60,45]])
# Out:
# C:\Users\LIANNAKA DADI\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.predict([[4,70,55]])
# Out:
# C:\Users\LIANNAKA DADI\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
print("Predicted:", y_pred)
print("Actual:", y_test.values)
# Out:
# Predicted: [1 1 1 0]
# Actual: [1 1 1 0]

# %%
print("Training Accuracy:", model.score(X_train, y_train))
print("Testing Accuracy:", model.score(X_test, y_test))
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 1.0

# %%
# New student data
new_student = [[6, 80, 65]]

# Predict
prediction = model.predict(new_student)

print("Prediction:", prediction)
# Out:
# Prediction: [1]
# C:\Users\LIANNAKA DADI\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
