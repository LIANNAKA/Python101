# %%
# %pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\liannaka dadi\appdata\roaming\python\python313\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\liannaka dadi\appdata\roaming\python\python313\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\liannaka dadi\appdata\roaming\python\python313\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\liannaka dadi\appdata\roaming\python\python313\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\liannaka dadi\appdata\roaming\python\python313\site-packages (from requests) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/recent"

headers = {
    "X-RapidAPI-Key": "45237040admsh497079831cfda18p1e5555jsn31d4d2c6adc0",
    "X-RapidAPI-Host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

data = response.json()
print(data)
# Out:
# {'typeMatches': [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 11253, 'seriesName': "ICC Men's T20 World Cup 2026", 'matches': [{'matchInfo': {'matchId': 139489, 'seriesId': 11253, 'seriesName': "ICC Men's T20 World Cup 2026", 'matchDesc': 'Final', 'matchFormat': 'T20', 'startDate': '1772976600000', 'endDate': '1772989200000', 'state': 'Complete', 'status': 'India won by 96 runs', 'team1': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'team2': {'teamId': 13, 'teamName': 'New Zealand', 'teamSName': 'NZ', 'imageId': 776333}, 'venueInfo': {'id': 50, 'ground': 'Narendra Modi Stadium', 'city': 'Ahmedabad', 'timezone': '+05:30', 'latitude': '23.091785', 'longitude': '72.597465'}, 'currBatTeamId': 2, 'seriesStartDt': '1770422400000', 'seriesEndDt': '1773100800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won', 'isFantasyEnabled': True}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 255, 'wickets': 5, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId': 2, 'runs': 159, 'wickets': 10, 'overs': 18.6}}}}, {'matchInfo': {'matchId': 139478, 'seriesId': 11253, 'seriesName': "ICC Men's T20 World Cup 2026", 'matchDesc': '2nd Semi-Final', 'matchFormat': 'T20', 'startDate': '1772717400000', 'endDate': '1772730000000', 'state': 'Complete', 'status': 'India won by 7 runs', 'team1': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'team2': {'teamId': 9, 'teamName': 'England', 'teamSName': 'ENG', 'imageId': 776237}, 'venueInfo': {'id': 81, 'ground': 'Wankhede Stadium', 'city': 'Mumbai', 'timezone': '+05:30', 'latitude': '18.938956', 'longitude': '72.825719'}, 'currBatTeamId': 2, 'seriesStartDt': '1770422400000', 'seriesEndDt': '1773100800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won', 'isFantasyEnabled': True}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 253, 'wickets': 7, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId': 2, 'runs': 246, 'wickets': 7, 'overs': 19.6}}}}, {'matchInfo': {'matchId': 139472, 'seriesId': 11253, 'seriesName': "ICC Men's T20 World Cup 2026", 'matchDesc': '1st Semi-Final', 'matchFormat': 'T20', 'startDate': '1772631000000', 'endDate': '1772643600000', 'state': 'Complete', 'status': 'New Zealand won by 9 wkts', 'team1': {'teamId': 11, 'teamName': 'South Africa', 'teamSName': 'RSA', 'imageId': 776287}, 'team2': {'teamId': 13, 'teamName': 'New Zealand', 'teamSName': 'NZ', 'imageId': 776333}, 'venueInfo': {'id': 31, 'ground': 'Eden Gardens', 'city': 'Kolkata', 'timezone': '+05:30', 'latitude': '22.564527', 'longitude': '88.343247'}, 'currBatTeamId': 13, 'seriesStartDt': '1770422400000', 'seriesEndDt': '1773100800000', 'isTimeAnnounced': True, 'stateTitle': 'NZ Won', 'isFantasyEnabled': True}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 169, 'wickets': 8, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId': 2, 'runs': 173, 'wickets': 1, 'overs': 12.5}}}}]}}, {'seriesAdWrapper': {'seriesId': 11570, 'seriesName': "ICC Men's T20 2028 World Cup Americas Sub Regional Qualifier B, 2026", 'matches': [{'matchInfo': {'matchId': 147535, 'seriesId': 11570, 'seriesName': "ICC Men's T20 2028 World Cup Americas Sub Regional Qualifier B, 2026", 'matchDesc': '4th Match', 'matchFormat': 'T20', 'startDate': '1773084600000', 'endDate': '1773097200000', 'state': 'Complete', 'status': 'Cayman Islands won by 9 wkts', 'team1': {'teamId': 544, 'teamName': 'Mexico', 'teamSName': 'MEX', 'imageId': 172595}, 'team2': {'teamId': 1020, 'teamName': 'Cayman Islands', 'teamSName': 'CAYM', 'imageId': 248399}, 'venueInfo': {'id': 892, 'ground': 'Jimmy Powell Oval', 'city': 'George Town', 'timezone': '-05:00', 'latitude': '19.286932', 'longitude': '-81.367439'}, 'currBatTeamId': 1020, 'seriesStartDt': '1772928000000', 'seriesEndDt': '1773792000000', 'isTimeAnnounced': True, 'stateTitle': 'CAYM Won'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 94, 'wickets': 9, 'overs':  ...

# %%
import pandas as pd

df = pd.json_normalize(data)

print(df.head())
# Out:
#                                          typeMatches responseLastUpdated  \
# 0  [{'matchType': 'International', 'seriesMatches...          1773164943
#
#                           filters.matchType  \
# 0  [International, League, Domestic, Women]
#
#                                   appIndex.seoTitle  \
# 0  Live Cricket Score - Scorecard and Match Results
#
#                          appIndex.webURL
# 0  www.cricbuzz.com/live-cricket-scores/

# %%
import os

API_KEY = os.getenv("RAPIDAPI_KEY")
